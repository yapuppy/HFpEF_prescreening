# %% [markdown]
# # Import function

# %%
import os
import keras
import warnings
warnings.filterwarnings("ignore")
from whole_function2 import *
print("tensorflow version:",tf.__version__)
print("keras version:",keras.__version__)
#opencv-python==3.4.3.18
# np.set_printoptions(suppress=True)
A4C_LV_model,A4C_LA_model,A2C_LV_model,A2C_LA_model,PSAX_big_model,PSAX_small_model =loading_model(3)
# Out:
# Using TensorFlow backend.
# C:\Users\Linlab\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Linlab\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Linlab\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # U-net Demo

# %%
A4C_path = "F:/馬交計畫_洪/code/20200915_code_upload/1BUAGS0U"
A4C_LV_whole_area,A4C_LA_whole_area,A4C_LV_whole_LV_volum,A4C_LA_whole_LV_volum,A4C_LV_whole_length,A4C_LA_whole_length,A4C_LV_whole_width,A4C_LA_whole_width,Vol,Len, Wid, Area, LV_all,LA_all = A4C_all_2(A4C_path,A4C_LV_model,A4C_LA_model,A=2)
# Out:
# (98, 434, 636, 3)
# ...
# 98/98 [==============================] - 1s 13ms/step
# shape: 98
# A4C_LV_big 68
# shapeimage: 4.05

# %% [markdown]
# # 1D-CNN Demo

# %%
import os
import sys
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from tqdm.tqdm import tqdm #windows
from tqdm import tqdm
from itertools import chain
import skimage
from skimage import io, transform, morphology
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
import skimage.transform as trans
from keras.models import Model, load_model
from keras.layers import Input ,Dropout
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
import tensorflow as tf
from numpy import *
from PIL import Image
import glob
from keras.layers import *#這行是關鍵(解決zero concentrate問題
from keras import optimizers
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.utils import np_utils
from keras.optimizers import SGD,RMSprop,Adam
from keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
# Out:
# Using TensorFlow backend.
# /home/linlab/anaconda3/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/linlab/anaconda3/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/linlab/anaconda3/envs/py3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
filename = "LA_A.csv"
model_name = "A4C_LA_A.h5"

# %%
Demo_data = Test_data[1].reshape(1,60)
Demo_label = Test_label_one[1]

# %%
model_path = "/media/linlab/Seagate Backup Plus Drive/馬交計畫_洪/code/20200915_code_upload/model/"+ model_name
model_m = load_model(model_path)

# score = model_m.evaluate(Demo_data,Demo_label)
# print("Test Accuracy:",round(score[1],2))
# Out:
# 771/771 [==============================] - 1s 2ms/step
# Test Accuracy: 0.85

# %%
print(model_m.predict(Demo_data))
print(model_m.predict_classes(Demo_data))
# Out:
# [[0.00440777 0.9955922 ]]
# [1]
